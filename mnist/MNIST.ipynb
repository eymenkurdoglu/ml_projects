# %% [markdown]
# ## MNIST at a glance

# %%
from sklearn.datasets import fetch_mldata
mnist = fetch_mldata('MNIST original')
# Datasets loaded by Scikit-Learn generally have a similar dictionary structure including:
# • A DESCR key describing the dataset
# • A "data" key containing an array with one row per instance and one column per feature
# • A "target" key containing an array with the labels

# %%
X, y = mnist["data"], mnist["target"]
N, d = X.shape
print( "Dataset size: {}, dimension: {}".format(N, d) )

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

digit = X[20000]
digit = digit.reshape( 28, 28 )
plt.imshow( digit, cmap = matplotlib.cm.binary, interpolation = "nearest" )
plt.axis("off")

# %%
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
sss = StratifiedShuffleSplit( n_splits = 1, test_size = 0.1, random_state = 42 )
for train_index, test_index in sss.split( X, y ):
    Xtrain = X[train_index]
    ytrain = y[train_index]
    Xtest = X[test_index]
    ytest = y[test_index]
Xtrain.shape

# %% [markdown]
# ## Training a Binary Classifier (3-Detector)

# %%
ytrain_th = (ytrain == 3)
ytest_th = (ytest == 3)

# %% [markdown]
# ### SGD

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier( max_iter = 1000, tol = 1e-3, random_state = 42 )
sgd_clf.fit( Xtrain, ytrain_th )
sgd_clf.predict( [X[20000]] )

# %%
from sklearn.model_selection import cross_val_score
cross_val_score( sgd_clf, Xtrain, ytrain_th, cv = 10, scoring = "accuracy" )

# %% [markdown]
# ## Random forests

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
forest_clf = RandomForestClassifier( random_state = 42 )
y_probas_forest = cross_val_predict( forest_clf, Xtrain, ytrain, cv = 10, method="predict_proba")

# %% [markdown]
# # Neural Nets with Tensorflow

# %%
import tensorflow as tf

tf.reset_default_graph()

# architecture
d, n_hid1, n_hid2, n_out = 28*28, 300, 100, 10

# during the execution phase, X will be replaced with one training batch at a time
# all the instances in a training batch will be processed simultaneously by the network
X = tf.placeholder( tf.float32, shape = (None, d), name = "X" ) # Shape[0]: data set size
y = tf.placeholder( tf.int64, shape = (None), name = "y" )

from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = fully_connected( X, n_hid1, scope = "hidden1" )
    hidden2 = fully_connected( hidden1, n_hid2, scope = "hidden2" )
    logits = fully_connected( hidden2, n_out, scope = "outputs", activation_fn = None )

with tf.name_scope("loss"):
    # softmax_cross_entropy_with_logits() -> takes one-hot vectors
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits( labels = y, logits = logits )
    loss = tf.reduce_mean( xentropy, name = "loss" )
    
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer( learning_rate )
    training_op = optimizer.minimize( loss )
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k( logits, y, 1 )
    accuracy = tf.reduce_mean( tf.cast( correct, tf.float32 ) )
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# EXECUTION PHASE
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")

n_epochs, batch_size = 400, 50

with tf.Session() as sesh:
    init.run()
    for epoch in range(n_epochs):
        for it in range( mnist.train.num_examples // batch_size ):
            Xbatch, ybatch = mnist.train.next_batch( batch_size )
            sesh.run( training_op, feed_dict = { X: Xbatch, y: ybatch } )
        acc_train = accuracy.eval( feed_dict = { X: Xbatch, y: ybatch } )
        acc_test = accuracy.eval( feed_dict = { X: mnist.test.images, y: mnist.test.labels } )
        print( epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test )
    save_path = saver.save( sesh, "./mnist_final_model.ckpt" )
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# 0 Train accuracy: 0.94 Test accuracy: 0.902
# 1 Train accuracy: 0.9 Test accuracy: 0.9207
# 2 Train accuracy: 0.96 Test accuracy: 0.9296
# 3 Train accuracy: 0.98 Test accuracy: 0.9344
# 4 Train accuracy: 0.98 Test accuracy: 0.9425
# 5 Train accuracy: 0.94 Test accuracy: 0.9471
# 6 Train accuracy: 0.98 Test accuracy: 0.9524
# 7 Train accuracy: 0.94 Test accuracy: 0.9541
# 8 Train accuracy: 0.92 Test accuracy: 0.9567
# 9 Train accuracy: 1.0 Test accuracy: 0.9602
# 10 Train accuracy: 0.96 Test accuracy: 0.9613
# 11 Train accuracy: 0.98 Test accuracy: 0.964
# 12 Train accuracy: 0.98 Test accuracy: 0.9651
# 13 Train accuracy: 0.96 Test accuracy: 0.9664
# 14 Train accuracy: 0.98 Test accuracy: 0.9666
# 15 Train accuracy: 0.96 Test accuracy: 0.9683
# 16 Train accuracy: 1.0 Test accuracy: 0.9683
# 17 Train accuracy: 0.98 Test accuracy: 0.9695
# 18 Train accuracy: 1.0 Test accuracy: 0.9712
# 19 Train accuracy: 0.98 Test accuracy: 0.9715
# 20 Train accuracy: 0.98 Test accuracy: 0.9722
# 21 Train accuracy: 1.0 Test accuracy: 0.9736
# 22 Train accuracy: 1.0 Test accuracy: 0.9735
# 23 Train accuracy: 0.98 Test accuracy: 0.9751
# 24 Train accuracy: 0.98 Test accuracy: 0.9748
# 25 Train accuracy: 0.96 Test accuracy: 0.9747
# 26 Train accuracy: 0.98 Test accuracy: 0.9745
# 27 Train accuracy: 0.96 Test accuracy: 0.9742
# 28 Train accuracy: 1.0 Test accuracy: 0.9754
# 29 Train accuracy: 0.98 Test accuracy: 0.9765
# 30 Train accuracy: 0.96 Test accuracy: 0.9755
# 31 Train accuracy: 1.0 Test accuracy: 0.9756
# 32 Train accuracy: 1.0 Test accuracy: 0.9758
# 33 Train accuracy: 1.0 Test accuracy: 0.9774
# 34 Train accuracy: 1.0 Test accuracy: 0.9765
# 35 Train accuracy: 1.0 Test accuracy: 0.9776
# 36 Train accuracy: 1.0 Test accuracy: 0.9772
# 37 Train accuracy: 1.0 Test accuracy: 0.9774
# 38 Train accuracy: 1.0 Test accuracy: 0.977
# 39 Train accuracy: 1.0 Test accuracy: 0.9769
# 40 Train accuracy: 1.0 Test accuracy: 0.978
# 41 Train accuracy: 1.0 Test accuracy: 0.9776
# 42 Train accuracy: 1.0 Test accuracy: 0.9786
# 43 Train accuracy: 1.0 Test accuracy: 0.9781
# 44 Train accuracy: 1.0 Test accuracy: 0.9777
# 45 Train accuracy: 1.0 Test accuracy: 0.9783
# 46 Train accuracy: 1.0 Test accuracy: 0.9782
# 47 Train accuracy: 1.0 Test accuracy: 0.9786
# 48 Train accuracy: 1.0 Test accuracy: 0.9784
# 49 Train accuracy: 1.0 Test accuracy: 0.9772
# 50 Train accuracy: 1.0 Test accuracy: 0.9786
# 51 Train accuracy: 1.0 Test accuracy: 0.9796
# 52 Train accuracy: 1.0 Test accuracy: 0.9783
# 53 Train accuracy: 1.0 Test accuracy: 0.978
# 54 Train accuracy: 1.0 Test accuracy: 0.9785
# 55 Train accuracy: 1.0 Test accuracy: 0.9787
# 56 Train accuracy: 0.98 Test accuracy: 0.9795
# 57 Train accuracy: 1.0 Test accuracy: 0.979
# 58 Train accuracy: 1.0 Test accuracy: 0.9786
# 59 Train accuracy: 1.0 Test accuracy: 0.9783
# 60 Train accuracy: 1.0 Test accuracy: 0.9785
# 61 Train accuracy: 1.0 Test accuracy: 0.9798
# 62 Train accuracy: 1.0 Test accuracy: 0.9786
# 63 Train accuracy: 1.0 Test accuracy: 0.9777
# 64 Train accuracy: 1.0 Test accuracy: 0.9794
# 65 Train accuracy: 1.0 Test accuracy: 0.9781
# 66 Train accuracy: 1.0 Test accuracy: 0.9787
# 67 Train accuracy: 1.0 Test accuracy: 0.9786
# 68 Train accuracy: 1.0 Test accuracy: 0.9783
# 69 Train accuracy: 1.0 Test accuracy: 0.9784
# 70 Train accuracy: 1.0 Test accuracy: 0.9783
# 71 Train accuracy: 1.0 Test accuracy: 0.9794
# 72 Train accuracy: 1.0 Test accuracy: 0.9785
# 73 Train accuracy: 1.0 Test accuracy: 0.9787
# 74 Train accuracy: 1.0 Test accuracy: 0.9788
# 75 Train accuracy: 1.0 Test accuracy: 0.9787
# 76 Train accuracy: 1.0 Test accuracy: 0.9782
# 77 Train accuracy: 1.0 Test accuracy: 0.9787
# 78 Train accuracy: 1.0 Test accuracy: 0.979
# 79 Train accuracy: 1.0 Test accuracy: 0.9784
# 80 Train accuracy: 1.0 Test accuracy: 0.9786
# 81 Train accuracy: 1.0 Test accuracy: 0.9788
# 82 Train accuracy: 1.0 Test accuracy: 0.9786
# 83 Train accuracy: 1.0 Test accuracy: 0.9792
# 84 Train accuracy: 1.0 Test accuracy: 0.9782
# 85 Train accuracy: 1.0 Test accuracy: 0.979
# 86 Train accuracy: 1.0 Test accuracy: 0.979
# 87 Train accuracy: 1.0 Test accuracy: 0.9786
# 88 Train accuracy: 1.0 Test accuracy: 0.9788
# 89 Train accuracy: 1.0 Test accuracy: 0.9784
# 90 Train accuracy: 1.0 Test accuracy: 0.9784
# 91 Train accuracy: 1.0 Test accuracy: 0.9784
# 92 Train accuracy: 1.0 Test accuracy: 0.9782
# 93 Train accuracy: 1.0 Test accuracy: 0.9784
# 94 Train accuracy: 1.0 Test accuracy: 0.9789
# 95 Train accuracy: 1.0 Test accuracy: 0.979
# 96 Train accuracy: 1.0 Test accuracy: 0.9785
# 97 Train accuracy: 1.0 Test accuracy: 0.9792
# 98 Train accuracy: 1.0 Test accuracy: 0.9786
# 99 Train accuracy: 1.0 Test accuracy: 0.979
# 100 Train accuracy: 1.0 Test accuracy: 0.9793
# 101 Train accuracy: 1.0 Test accuracy: 0.9796
# 102 Train accuracy: 1.0 Test accuracy: 0.9786
# 103 Train accuracy: 1.0 Test accuracy: 0.9788
# 104 Train accuracy: 1.0 Test accuracy: 0.9794
# 105 Train accuracy: 1.0 Test accuracy: 0.9785
# 106 Train accuracy: 1.0 Test accuracy: 0.9785
# 107 Train accuracy: 1.0 Test accuracy: 0.9786
# 108 Train accuracy: 1.0 Test accuracy: 0.979
# 109 Train accuracy: 1.0 Test accuracy: 0.9788
# 110 Train accuracy: 1.0 Test accuracy: 0.9784
# 111 Train accuracy: 1.0 Test accuracy: 0.979
# 112 Train accuracy: 1.0 Test accuracy: 0.9787
# 113 Train accuracy: 1.0 Test accuracy: 0.9792
# 114 Train accuracy: 1.0 Test accuracy: 0.9793
# 115 Train accuracy: 1.0 Test accuracy: 0.9791
# 116 Train accuracy: 1.0 Test accuracy: 0.9787
# 117 Train accuracy: 1.0 Test accuracy: 0.9789
# 118 Train accuracy: 1.0 Test accuracy: 0.9788
# 119 Train accuracy: 1.0 Test accuracy: 0.9791
# 120 Train accuracy: 1.0 Test accuracy: 0.9793
# 121 Train accuracy: 1.0 Test accuracy: 0.9791
# 122 Train accuracy: 1.0 Test accuracy: 0.979
# 123 Train accuracy: 1.0 Test accuracy: 0.979
# 124 Train accuracy: 1.0 Test accuracy: 0.9789
# 125 Train accuracy: 1.0 Test accuracy: 0.9797
# 126 Train accuracy: 1.0 Test accuracy: 0.9792
# 127 Train accuracy: 1.0 Test accuracy: 0.9793
# 128 Train accuracy: 1.0 Test accuracy: 0.9789
# 129 Train accuracy: 1.0 Test accuracy: 0.9793
# 130 Train accuracy: 1.0 Test accuracy: 0.9785
# 131 Train accuracy: 1.0 Test accuracy: 0.9794
# 132 Train accuracy: 1.0 Test accuracy: 0.979
# 133 Train accuracy: 1.0 Test accuracy: 0.9791
# 134 Train accuracy: 1.0 Test accuracy: 0.9791
# 135 Train accuracy: 1.0 Test accuracy: 0.979
# 136 Train accuracy: 1.0 Test accuracy: 0.9792
# 137 Train accuracy: 1.0 Test accuracy: 0.9792
# 138 Train accuracy: 1.0 Test accuracy: 0.9787
# 139 Train accuracy: 1.0 Test accuracy: 0.9791
# 140 Train accuracy: 1.0 Test accuracy: 0.979
# 141 Train accuracy: 1.0 Test accuracy: 0.9788
# 142 Train accuracy: 1.0 Test accuracy: 0.9791
# 143 Train accuracy: 1.0 Test accuracy: 0.9788
# 144 Train accuracy: 1.0 Test accuracy: 0.9792
# 145 Train accuracy: 1.0 Test accuracy: 0.9787
# 146 Train accuracy: 1.0 Test accuracy: 0.9789
# 147 Train accuracy: 1.0 Test accuracy: 0.9792
# 148 Train accuracy: 1.0 Test accuracy: 0.9787
# 149 Train accuracy: 1.0 Test accuracy: 0.9787
# 150 Train accuracy: 1.0 Test accuracy: 0.9789
# 151 Train accuracy: 1.0 Test accuracy: 0.9786
# 152 Train accuracy: 1.0 Test accuracy: 0.9792
# 153 Train accuracy: 1.0 Test accuracy: 0.9791
# 154 Train accuracy: 1.0 Test accuracy: 0.9792
# 155 Train accuracy: 1.0 Test accuracy: 0.9786
# 156 Train accuracy: 1.0 Test accuracy: 0.9787
# 157 Train accuracy: 1.0 Test accuracy: 0.979
# 158 Train accuracy: 1.0 Test accuracy: 0.9788
# 159 Train accuracy: 1.0 Test accuracy: 0.9791
# 160 Train accuracy: 1.0 Test accuracy: 0.9788
# 161 Train accuracy: 1.0 Test accuracy: 0.9789
# 162 Train accuracy: 1.0 Test accuracy: 0.9791
# 163 Train accuracy: 1.0 Test accuracy: 0.9793
# 164 Train accuracy: 1.0 Test accuracy: 0.979
# 165 Train accuracy: 1.0 Test accuracy: 0.9789
# 166 Train accuracy: 1.0 Test accuracy: 0.9792
# 167 Train accuracy: 1.0 Test accuracy: 0.9786
# 168 Train accuracy: 1.0 Test accuracy: 0.9788
# 169 Train accuracy: 1.0 Test accuracy: 0.9789
# 170 Train accuracy: 1.0 Test accuracy: 0.9789
# 171 Train accuracy: 1.0 Test accuracy: 0.9791
# 172 Train accuracy: 1.0 Test accuracy: 0.979
# 173 Train accuracy: 1.0 Test accuracy: 0.9787
# 174 Train accuracy: 1.0 Test accuracy: 0.9787
# 175 Train accuracy: 1.0 Test accuracy: 0.9791
# 176 Train accuracy: 1.0 Test accuracy: 0.9792
# 177 Train accuracy: 1.0 Test accuracy: 0.9789
# 178 Train accuracy: 1.0 Test accuracy: 0.979
# 179 Train accuracy: 1.0 Test accuracy: 0.9788
# 180 Train accuracy: 1.0 Test accuracy: 0.9791
# 181 Train accuracy: 1.0 Test accuracy: 0.9789
# 182 Train accuracy: 1.0 Test accuracy: 0.9788
# 183 Train accuracy: 1.0 Test accuracy: 0.9792
# 184 Train accuracy: 1.0 Test accuracy: 0.979
# 185 Train accuracy: 1.0 Test accuracy: 0.9791
# 186 Train accuracy: 1.0 Test accuracy: 0.9791
# 187 Train accuracy: 1.0 Test accuracy: 0.9788
# 188 Train accuracy: 1.0 Test accuracy: 0.9791
# 189 Train accuracy: 1.0 Test accuracy: 0.9793
# 190 Train accuracy: 1.0 Test accuracy: 0.9789
# 191 Train accuracy: 1.0 Test accuracy: 0.979
# 192 Train accuracy: 1.0 Test accuracy: 0.9792
# 193 Train accuracy: 1.0 Test accuracy: 0.9792
# 194 Train accuracy: 1.0 Test accuracy: 0.9791
# 195 Train accuracy: 1.0 Test accuracy: 0.979
# 196 Train accuracy: 1.0 Test accuracy: 0.9789
# 197 Train accuracy: 1.0 Test accuracy: 0.979
# 198 Train accuracy: 1.0 Test accuracy: 0.979
# 199 Train accuracy: 1.0 Test accuracy: 0.9792
# 200 Train accuracy: 1.0 Test accuracy: 0.9789
# 201 Train accuracy: 1.0 Test accuracy: 0.9792
# 202 Train accuracy: 1.0 Test accuracy: 0.9791
# 203 Train accuracy: 1.0 Test accuracy: 0.9789
# 204 Train accuracy: 1.0 Test accuracy: 0.9789
# 205 Train accuracy: 1.0 Test accuracy: 0.9791
# 206 Train accuracy: 1.0 Test accuracy: 0.9789
# 207 Train accuracy: 1.0 Test accuracy: 0.9788
# 208 Train accuracy: 1.0 Test accuracy: 0.9791
# 209 Train accuracy: 1.0 Test accuracy: 0.979
# 210 Train accuracy: 1.0 Test accuracy: 0.9791
# 211 Train accuracy: 1.0 Test accuracy: 0.9793
# 212 Train accuracy: 1.0 Test accuracy: 0.9791
# 213 Train accuracy: 1.0 Test accuracy: 0.979
# 214 Train accuracy: 1.0 Test accuracy: 0.9787
# 215 Train accuracy: 1.0 Test accuracy: 0.9793
# 216 Train accuracy: 1.0 Test accuracy: 0.979
# 217 Train accuracy: 1.0 Test accuracy: 0.9792
# 218 Train accuracy: 1.0 Test accuracy: 0.9791
# 219 Train accuracy: 1.0 Test accuracy: 0.9791
# 220 Train accuracy: 1.0 Test accuracy: 0.9792
# 221 Train accuracy: 1.0 Test accuracy: 0.9791
# 222 Train accuracy: 1.0 Test accuracy: 0.9791
# 223 Train accuracy: 1.0 Test accuracy: 0.9791
# 224 Train accuracy: 1.0 Test accuracy: 0.9791
# 225 Train accuracy: 1.0 Test accuracy: 0.9792
# 226 Train accuracy: 1.0 Test accuracy: 0.979
# 227 Train accuracy: 1.0 Test accuracy: 0.9789
# 228 Train accuracy: 1.0 Test accuracy: 0.9791
# 229 Train accuracy: 1.0 Test accuracy: 0.9791
# 230 Train accuracy: 1.0 Test accuracy: 0.979
# 231 Train accuracy: 1.0 Test accuracy: 0.979
# 232 Train accuracy: 1.0 Test accuracy: 0.9793
# 233 Train accuracy: 1.0 Test accuracy: 0.9792
# 234 Train accuracy: 1.0 Test accuracy: 0.9792
# 235 Train accuracy: 1.0 Test accuracy: 0.9792
# 236 Train accuracy: 1.0 Test accuracy: 0.9792
# 237 Train accuracy: 1.0 Test accuracy: 0.9791
# 238 Train accuracy: 1.0 Test accuracy: 0.979
# 239 Train accuracy: 1.0 Test accuracy: 0.9791
# 240 Train accuracy: 1.0 Test accuracy: 0.9789
# 241 Train accuracy: 1.0 Test accuracy: 0.9791
# 242 Train accuracy: 1.0 Test accuracy: 0.9791
# 243 Train accuracy: 1.0 Test accuracy: 0.979
# 244 Train accuracy: 1.0 Test accuracy: 0.9792
# 245 Train accuracy: 1.0 Test accuracy: 0.9792
# 246 Train accuracy: 1.0 Test accuracy: 0.9789
# 247 Train accuracy: 1.0 Test accuracy: 0.9792
# 248 Train accuracy: 1.0 Test accuracy: 0.979
# 249 Train accuracy: 1.0 Test accuracy: 0.9793
# 250 Train accuracy: 1.0 Test accuracy: 0.9794
# 251 Train accuracy: 1.0 Test accuracy: 0.9792
# 252 Train accuracy: 1.0 Test accuracy: 0.9792
# 253 Train accuracy: 1.0 Test accuracy: 0.9793
# 254 Train accuracy: 1.0 Test accuracy: 0.9793
# 255 Train accuracy: 1.0 Test accuracy: 0.979
# 256 Train accuracy: 1.0 Test accuracy: 0.9793
# 257 Train accuracy: 1.0 Test accuracy: 0.9791
# 258 Train accuracy: 1.0 Test accuracy: 0.9792
# 259 Train accuracy: 1.0 Test accuracy: 0.9793
# 260 Train accuracy: 1.0 Test accuracy: 0.9794
# 261 Train accuracy: 1.0 Test accuracy: 0.979
# 262 Train accuracy: 1.0 Test accuracy: 0.9794
# 263 Train accuracy: 1.0 Test accuracy: 0.9791
# 264 Train accuracy: 1.0 Test accuracy: 0.9793
# 265 Train accuracy: 1.0 Test accuracy: 0.9792
# 266 Train accuracy: 1.0 Test accuracy: 0.9792
# 267 Train accuracy: 1.0 Test accuracy: 0.9789
# 268 Train accuracy: 1.0 Test accuracy: 0.9791
# 269 Train accuracy: 1.0 Test accuracy: 0.9792
# 270 Train accuracy: 1.0 Test accuracy: 0.9787
# 271 Train accuracy: 1.0 Test accuracy: 0.9791
# 272 Train accuracy: 1.0 Test accuracy: 0.9792
# 273 Train accuracy: 1.0 Test accuracy: 0.9793
# 274 Train accuracy: 1.0 Test accuracy: 0.9794
# 275 Train accuracy: 1.0 Test accuracy: 0.9792
# 276 Train accuracy: 1.0 Test accuracy: 0.9793
# 277 Train accuracy: 1.0 Test accuracy: 0.9792
# 278 Train accuracy: 1.0 Test accuracy: 0.9793
# 279 Train accuracy: 1.0 Test accuracy: 0.9793
# 280 Train accuracy: 1.0 Test accuracy: 0.9791
# 281 Train accuracy: 1.0 Test accuracy: 0.9789
# 282 Train accuracy: 1.0 Test accuracy: 0.9791
# 283 Train accuracy: 1.0 Test accuracy: 0.9791
# 284 Train accuracy: 1.0 Test accuracy: 0.9792
# 285 Train accuracy: 1.0 Test accuracy: 0.9791
# 286 Train accuracy: 1.0 Test accuracy: 0.9793
# 287 Train accuracy: 1.0 Test accuracy: 0.9792
# 288 Train accuracy: 1.0 Test accuracy: 0.9793
# 289 Train accuracy: 1.0 Test accuracy: 0.9792
# 290 Train accuracy: 1.0 Test accuracy: 0.9792
# 291 Train accuracy: 1.0 Test accuracy: 0.9792
# 292 Train accuracy: 1.0 Test accuracy: 0.9792
# 293 Train accuracy: 1.0 Test accuracy: 0.9793
# 294 Train accuracy: 1.0 Test accuracy: 0.9791
# 295 Train accuracy: 1.0 Test accuracy: 0.9792
# 296 Train accuracy: 1.0 Test accuracy: 0.979
# 297 Train accuracy: 1.0 Test accuracy: 0.9792
# 298 Train accuracy: 1.0 Test accuracy: 0.9792
# 299 Train accuracy: 1.0 Test accuracy: 0.9792
# 300 Train accuracy: 1.0 Test accuracy: 0.9795
# 301 Train accuracy: 1.0 Test accuracy: 0.979
# 302 Train accuracy: 1.0 Test accuracy: 0.9791
# 303 Train accuracy: 1.0 Test accuracy: 0.9792
# 304 Train accuracy: 1.0 Test accuracy: 0.9793
# 305 Train accuracy: 1.0 Test accuracy: 0.9792
# 306 Train accuracy: 1.0 Test accuracy: 0.9792
# 307 Train accuracy: 1.0 Test accuracy: 0.9793
# 308 Train accuracy: 1.0 Test accuracy: 0.9793
# 309 Train accuracy: 1.0 Test accuracy: 0.9791
# 310 Train accuracy: 1.0 Test accuracy: 0.9791
# 311 Train accuracy: 1.0 Test accuracy: 0.9794
# 312 Train accuracy: 1.0 Test accuracy: 0.9792
# 313 Train accuracy: 1.0 Test accuracy: 0.9791
# 314 Train accuracy: 1.0 Test accuracy: 0.9791
# 315 Train accuracy: 1.0 Test accuracy: 0.9794
# 316 Train accuracy: 1.0 Test accuracy: 0.9792
# 317 Train accuracy: 1.0 Test accuracy: 0.9791
# 318 Train accuracy: 1.0 Test accuracy: 0.9792
# 319 Train accuracy: 1.0 Test accuracy: 0.9792
# 320 Train accuracy: 1.0 Test accuracy: 0.9793
# 321 Train accuracy: 1.0 Test accuracy: 0.979
# 322 Train accuracy: 1.0 Test accuracy: 0.979
# 323 Train accuracy: 1.0 Test accuracy: 0.9791
# 324 Train accuracy: 1.0 Test accuracy: 0.9793
# 325 Train accuracy: 1.0 Test accuracy: 0.9793
# 326 Train accuracy: 1.0 Test accuracy: 0.979
# 327 Train accuracy: 1.0 Test accuracy: 0.9791
# 328 Train accuracy: 1.0 Test accuracy: 0.9791
# 329 Train accuracy: 1.0 Test accuracy: 0.9794
# 330 Train accuracy: 1.0 Test accuracy: 0.9791
# 331 Train accuracy: 1.0 Test accuracy: 0.9788
# 332 Train accuracy: 1.0 Test accuracy: 0.979
# 333 Train accuracy: 1.0 Test accuracy: 0.9792
# 334 Train accuracy: 1.0 Test accuracy: 0.9791
# 335 Train accuracy: 1.0 Test accuracy: 0.9794
# 336 Train accuracy: 1.0 Test accuracy: 0.9791
# 337 Train accuracy: 1.0 Test accuracy: 0.9794
# 338 Train accuracy: 1.0 Test accuracy: 0.9794
# 339 Train accuracy: 1.0 Test accuracy: 0.979
# 340 Train accuracy: 1.0 Test accuracy: 0.9791
# 341 Train accuracy: 1.0 Test accuracy: 0.9792
# 342 Train accuracy: 1.0 Test accuracy: 0.9792
# 343 Train accuracy: 1.0 Test accuracy: 0.9793
# 344 Train accuracy: 1.0 Test accuracy: 0.9793
# 345 Train accuracy: 1.0 Test accuracy: 0.9793
# 346 Train accuracy: 1.0 Test accuracy: 0.9795
# 347 Train accuracy: 1.0 Test accuracy: 0.9794
# 348 Train accuracy: 1.0 Test accuracy: 0.9794
# 349 Train accuracy: 1.0 Test accuracy: 0.9794
# 350 Train accuracy: 1.0 Test accuracy: 0.9791
# 351 Train accuracy: 1.0 Test accuracy: 0.9791
# 352 Train accuracy: 1.0 Test accuracy: 0.9792
# 353 Train accuracy: 1.0 Test accuracy: 0.9792
# 354 Train accuracy: 1.0 Test accuracy: 0.9793
# 355 Train accuracy: 1.0 Test accuracy: 0.9793
# 356 Train accuracy: 1.0 Test accuracy: 0.979
# 357 Train accuracy: 1.0 Test accuracy: 0.9792
# 358 Train accuracy: 1.0 Test accuracy: 0.979
# 359 Train accuracy: 1.0 Test accuracy: 0.9792
# 360 Train accuracy: 1.0 Test accuracy: 0.9793
# 361 Train accuracy: 1.0 Test accuracy: 0.9791
# 362 Train accuracy: 1.0 Test accuracy: 0.979
# 363 Train accuracy: 1.0 Test accuracy: 0.9791
# 364 Train accuracy: 1.0 Test accuracy: 0.9792
# 365 Train accuracy: 1.0 Test accuracy: 0.9792
# 366 Train accuracy: 1.0 Test accuracy: 0.9792
# 367 Train accuracy: 1.0 Test accuracy: 0.9793
# 368 Train accuracy: 1.0 Test accuracy: 0.9791
# 369 Train accuracy: 1.0 Test accuracy: 0.9792
# 370 Train accuracy: 1.0 Test accuracy: 0.9794
# 371 Train accuracy: 1.0 Test accuracy: 0.9793
# 372 Train accuracy: 1.0 Test accuracy: 0.9791
# 373 Train accuracy: 1.0 Test accuracy: 0.979
# 374 Train accuracy: 1.0 Test accuracy: 0.9791
# 375 Train accuracy: 1.0 Test accuracy: 0.9791
# 376 Train accuracy: 1.0 Test accuracy: 0.9793
# 377 Train accuracy: 1.0 Test accuracy: 0.979
# 378 Train accuracy: 1.0 Test accuracy: 0.9793
# 379 Train accuracy: 1.0 Test accuracy: 0.9791
# 380 Train accuracy: 1.0 Test accuracy: 0.9791
# 381 Train accuracy: 1.0 Test accuracy: 0.9792
# 382 Train accuracy: 1.0 Test accuracy: 0.9791
# 383 Train accuracy: 1.0 Test accuracy: 0.9792
# 384 Train accuracy: 1.0 Test accuracy: 0.9793
# 385 Train accuracy: 1.0 Test accuracy: 0.9793
# 386 Train accuracy: 1.0 Test accuracy: 0.979
# 387 Train accuracy: 1.0 Test accuracy: 0.9792
# 388 Train accuracy: 1.0 Test accuracy: 0.9791
# 389 Train accuracy: 1.0 Test accuracy: 0.9789
# 390 Train accuracy: 1.0 Test accuracy: 0.9793
# 391 Train accuracy: 1.0 Test accuracy: 0.9791
# 392 Train accuracy: 1.0 Test accuracy: 0.9792
# 393 Train accuracy: 1.0 Test accuracy: 0.9793
# 394 Train accuracy: 1.0 Test accuracy: 0.9789
# 395 Train accuracy: 1.0 Test accuracy: 0.9793
# 396 Train accuracy: 1.0 Test accuracy: 0.9792
# 397 Train accuracy: 1.0 Test accuracy: 0.9792
# 398 Train accuracy: 1.0 Test accuracy: 0.9791
# 399 Train accuracy: 1.0 Test accuracy: 0.9792
